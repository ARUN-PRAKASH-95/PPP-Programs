# %%
import numpy as np
import matplotlib.pyplot as plt

E = 75e9
h = np.linspace(-0.1,0.1,10)
a = 0.2
epsilon_yy = (50*h*12)/(E*a**4)
sigma = E*epsilon_yy
print(epsilon_yy)
print(sigma)


plt.plot(h,epsilon_yy)
# plt.plot(h,sigma)
# x = 100000/E
# print(x)
# Out:
# [-1.00000000e-07 -7.77777778e-08 -5.55555556e-08 -3.33333333e-08
#  -1.11111111e-08  1.11111111e-08  3.33333333e-08  5.55555556e-08
#   7.77777778e-08  1.00000000e-07]
# [-7500.         -5833.33333333 -4166.66666667 -2500.
#   -833.33333333   833.33333333  2500.          4166.66666667
#   5833.33333333  7500.        ]
