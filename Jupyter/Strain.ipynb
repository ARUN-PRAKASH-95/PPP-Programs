# %%
import numpy as np
import matplotlib.pyplot as plt

L = 2
E = 75e9
h = np.linspace(-0.1,0.1,10)
a = 0.2
epsilon_yy = (50*L*h*12)/(E*a**4)
sigma = E*epsilon_yy
print(epsilon_yy)
print(sigma)


plt.plot(h,epsilon_yy)
# plt.plot(h,sigma)
# Out:
# [-1.00000000e-06 -7.77777778e-07 -5.55555556e-07 -3.33333333e-07
#  -1.11111111e-07  1.11111111e-07  3.33333333e-07  5.55555556e-07
#   7.77777778e-07  1.00000000e-06]
# [-75000.         -58333.33333333 -41666.66666667 -25000.
#   -8333.33333333   8333.33333333  25000.          41666.66666667
#   58333.33333333  75000.        ]
