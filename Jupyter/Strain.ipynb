# %%
import numpy as np
import matplotlib.pyplot as plt

h = np.linspace(-0.1,0.1,10)
a = 0.2
epsilon_yy = (50*2*h*12)/(2*75e9*a**4)
sigma = (50*2*h*12)/(2*a**4)
print(epsilon_yy)
print(sigma)


# plt.plot(h,epsilon_yy)
plt.plot(h,sigma)
# Out:
# [-5.00000000e-07 -3.88888889e-07 -2.77777778e-07 -1.66666667e-07
#  -5.55555556e-08  5.55555556e-08  1.66666667e-07  2.77777778e-07
#   3.88888889e-07  5.00000000e-07]
# [-37500.         -29166.66666667 -20833.33333333 -12500.
#   -4166.66666667   4166.66666667  12500.          20833.33333333
#   29166.66666667  37500.        ]
